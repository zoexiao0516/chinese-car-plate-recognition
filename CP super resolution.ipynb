# %%
# clone TF-LAPSRN repository
# !git clone https://github.com/Saafke/EDSR_Tensorflow  # clone repo
# %cd EDSR_Tensorflow
# %ls -a
#!git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'EDSR_Tensorflow'...
# remote: Enumerating objects: 143, done.
# remote: Total 143 (delta 0), reused 0 (delta 0), pack-reused 143
# Receiving objects: 100% (143/143), 162.50 MiB | 32.76 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/TF-LAPSRN/EDSR_Tensorflow/EDSR_Tensorflow/EDSR_Tensorflow
# ./   data_utils.py  .git/    LICENSE  models/    run.py
# ../  edsr.py        images/  main.py  README.md

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python main.py --test --scale 4 --image /shared with me/ML/runs/detect/exp2/crops/Carplate
# Out:
# 2021-05-04 18:07:13.595302: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "main.py", line 3, in <module>
#     import run
#   File "/content/TF-LAPSRN/EDSR_Tensorflow/EDSR_Tensorflow/EDSR_Tensorflow/run.py", line 13, in <module>
#     from tensorflow.tools.graph_transforms import TransformGraph
# ModuleNotFoundError: No module named 'tensorflow.tools.graph_transforms'
